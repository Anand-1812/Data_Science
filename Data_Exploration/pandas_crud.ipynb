# %%
import pandas as pd

data = {
  "Name": ["Anand", "Sourav", "Ayush", "Narayan"],
  "Age": [20, 21, 21, 22],
  "City": ["Bhubaneswar", "Bhagalpur", "Pune", "Bhagalpur"]
}

df = pd.DataFrame(data)
# print(df)

# print(df.head(3), "\n")
# print(df.tail(2), "\n")

# print(df.columns, "\n")
# print(df.dtypes, "\n")
# print(df.describe(), "\n")
# print(df["Name"], "\n")
# print(df["City"].unique(), "\n")
# print(df[df["Age"] > 20])

print(df.iloc[0], "\n")
# Out:
# Name          Anand
# Age              20
# City    Bhubaneswar
# Name: 0, dtype: object

# %%
# updating data 

# 'Name' is the index of df, not a column, so select by index
df.loc["Anand", "Age"] = 12

# print(df)

# Deleting data
# drop the row at positional index 2 (third row). Since the index contains names,
# use df.index[2] to get the actual label to drop.
df.drop(columns=['City'], inplace=True)
print(df)

del df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 4
#       1 # updating data
#       2
#       3 # 'Name' is the index of df, not a column, so select by index
# ----> 4 df.loc["Anand", "Age"] = 12
#       6 # print(df)
#       7
#       8 # Deleting data
#       9 # drop the row at positional index 2 (third row). Since the index contains names,
#      10 # use df.index[2] to get the actual label to drop.
#      11 df.drop(columns=['City'], inplace=True)
#
# NameError: name 'df' is not defined

# %%
card_df = pd.read_csv("CAR.csv")
print(card_df.head())
