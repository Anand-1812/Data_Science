# %%
# Built on top of matplotlib and pandas

import pandas as pd
import seaborn as sborn
import matplotlib.pyplot as plt

data = {'Name': ['ANSH', 'SAHIL', 'JAYAN', 'ANURAG'], 'Age': [21, 23, 20, 24]}
df = pd.DataFrame(data)

sborn.lineplot(x=df.index, y='Age', data=df)
plt.show()

# %%
# Scatter plot: relationship btw numerical values


data = {'Name': ['ANSH', 'SAHIL', 'JAYAN', 'ANURAG'], 'Age': [21, 23, 20, 45]}
df = pd.DataFrame(data)

# sborn.scatterplot(x=df.index, y='Age', data=df)
# plt.show()

# Box plot: qaurtiles vs cateogrical data

sborn.boxplot(y='Age', data=df)
plt.show()

# %%
# Violin plot: similar as box plot but with more categorical data

sborn.violinplot(y='Age', data=df)
plt.show()

# swarm plot: display individual data points withotu overlap

sborn.swarmplot(x=df.index, y='Age', data=df)
plt.show()

# %%
# Bar plot: estimate of central tendency for a numerical value 

data = {'Name': ['ANSH', 'SAHIL', 'JAYAN', 'ANURAG'], 'Age': [21, 23, 20, 24]}
df = pd.DataFrame(data)

sborn.barplot(x='Name', y='Age', data=df)
plt.show()

# point plot: point estimates and confidence interval using scatter glyphs

sborn.pointplot(x='Name', y='Age', data=df)
plt.show()

# %%
# count plot: disply the number of each category using bars to visualize

data = {'Name': ['ANSH', 'SAHIL', 'ANSH', 'JAYAN', 'ANURAG', 'ANURAG', 'ANURAG', 'SAHIL']}
df = pd.DataFrame(data)

sborn.countplot(x='Name', data=df)
plt.title("Frequency of Names")
plt.show()

# %%
from sklearn.datasets import load_iris

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['Species'] = iris.target
df['Species'] = df['Species'].map({ 0: 'Setosa', 1: 'Versicolor', 2: 'Virginica'})

sborn.kdeplot(data=df[df['Species'] == 'Virginica'], x='sepal length (cm)', fill=True, label='Virginica')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 8
#       5 df['Species'] = iris.target
#       6 df['Species'] = df['Species'].map({ 0: 'Setosa', 1: 'Versicolor', 2: 'Virginica'})
# ----> 8 sborn.kdeplot(data=df[df['Species'] == 'Virginica'], x='sepal length(cm)', fill=True, label='Virginica')
#       9 plt.legend()
#      10 plt.show()
#
# File ~/Coding/Data_Science/.venv/lib/python3.13/site-packages/seaborn/distributions.py:1669, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1665 levels = kwargs.pop("n_levels", levels)
#    1667 # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - #
# -> 1669 p = _DistributionPlotter(
#    1670     data=data,
#    1671     variables=dict(x=x, y=y, hue=hue, weights=weights),
#    1672 )
#    1674 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#    1676 if ax is None:
#
# File ~/Coding/Data_Science/.venv/lib/python3.13/site-packages/seaborn/distributions.py:110, in _DistributionPlotter.__init__(self, data, variables)
#     104 def __init__(
#     105     self,
#     106     data=None,
#     107     variables={},
#     108 ):
# --> 110     super().__init__(data=data, variables=variables)
#
# File ~/Coding/Data_Science/.venv/lib/python3.13/site-packages/seaborn/_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File ~/Coding/Data_Science/.venv/lib/python3.13/site-packages/seaborn/_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File ~/Coding/Data_Science/.venv/lib/python3.13/site-packages/seaborn/_core/data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File ~/Coding/Data_Science/.venv/lib/python3.13/site-packages/seaborn/_core/data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `sepal length(cm)` for `x`. An entry with this name does not appear in `data`.
